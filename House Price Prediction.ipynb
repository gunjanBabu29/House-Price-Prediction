# %% [markdown]
# <center><img src="https://i.ibb.co/sv00XQ7/download.png"></center>

# %% [markdown]
# <h2><center>Machine Learning Project</h2></center>

# %% [markdown]
# <h3><center style= "color:Red;"> Project-ML1) Gunjan Kumar
#     <br>Depart: B.Tech CSE </br> <br>3rd Year</br></center></h3>

# %% [markdown]
# <center><h2 style="color:blue;"> Project Title : 🏠House Price Prediction🏠<h2></center>

# %% [markdown]
# ## Project Objective :

# %% [markdown]
# ### The objective is to create a precise machine learning model using a house price prediction dataset in Python, aiding pricing decisions and market efficiency.

# %% [markdown]
# ### Performing following Regresson algo for model building in this project:
# #### 1. Linear Regression
# #### 2. Ridge Regression
# #### 3. Lasso Regression

# %% [markdown]
# ## Steps and Tasks :

# %% [markdown]
# ### Step 1 : Reading and understanding of data

# %% [markdown]
# ### Step 2 : Data cleaning and Preparation

# %% [markdown]
# ### Step 3 : Visualizing the data

# %% [markdown]
# ### Step 4 : Train-Test Split and feature scaling

# %% [markdown]
# ### Step 5 : Model Building

# %% [markdown]
# ### Step 6 : Accuracy and Evaluation

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Step 1 : Reading and understanding of data

# %%
# importing All required libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset from file location
data = pd.read_csv("C:\/Users\/gunja/\Desktop\/Internship/\Projects/\house-price-prediction-2/\kc_house_data.csv")

# %%
#printing top 5 row
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#descrbe about data of dataset
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#finding all details from dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ## Step 2 : Data cleaning and Preparation

# %%
#print null values are available or not
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#looking for total unique values in view column
data['view'].unique()
# Out:
# array([0, 3, 4, 2, 1], dtype=int64)

# %%
#count of unique values
data['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %% [markdown]
# ## Step 3 : Visualizing the data

# %%
#count total values in bedrooms and draw barchart
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Floor')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price,data.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
#Bar plot for bedrooms and price
plt.figure(figsize=(15,6))
sns.barplot(x = 'bedrooms', y = 'price', data = data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
# Histograms of each feature
data.hist(bins=20, color='red', figsize=(14, 10))
plt.show()

# %%
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

# %%
data.floors.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Step 4 : Train-Test Split and feature scaling

# %%
# separating target and features for the train_test_split (y=target, x=feature)
y = data[['price']]
x=data.drop(['id', 'price', 'date'],axis=1)

# %%
#importing library for train_test_split the data
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y, test_size = 0.2,random_state =2)

# %% [markdown]
# ## Step 5 : Model Building

# %% [markdown]
# ### Ridge Regression
# To combat the issue of overfitting in linear regression models, ridge regression is a regularization approach. The size of the coefficients is reduced and overfitting is prevented by adding a penalty term to the cost function of linear regression.

# %%
#importing model for Ridge Regression from Sklearn
from sklearn.linear_model import Ridge

# %%
#model building
ridge = Ridge(alpha=0.001)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.001)

# %%
#finding total accuracy comes in Ridge Regression
print("Acuuracy of training data=",ridge.score(x_train, y_train)) #accuracy of trained data
print("Acuuracy of testing data=",ridge.score(x_test, y_test)) #accuracy of test data
# Out:
# Acuuracy of training data= 0.6954859820412311
# Acuuracy of testing data= 0.7156152846161428

# %% [markdown]
# ### Lasso Regression
# Lasso regression, commonly referred to as L1 regularization, is a method for stopping overfitting in linear regression models by including a penalty term in the cost function

# %%
#importing model for Lasso Regression from Sklearn
from sklearn.linear_model import Lasso

# %%
#model building
lasso = Lasso(alpha=0.01)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
#finding total accuracy comes in Lasso Regression
print("Acuuracy of training data=",lasso.score(x_train, y_train)) #accuracy of trained data
print("Acuuracy of testing data=",lasso.score(x_test, y_test)) #accuracy of test datav
# Out:
# Acuuracy of training data= 0.695485982043033
# Acuuracy of testing data= 0.7156152906219972

# %% [markdown]
# ### Linear Regression
# Linear regression is a type of supervised machine learning algorithm that computes the linear relationship between a dependent variable and one or more independent features. When the number of the independent feature, is 1 then it is known as Univariate Linear regression, and in the case of more than one feature, it is known as multivariate linear regression.

# %%
#importing model for LinearRegression from Sklearn
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
#Building model (fit x_train in model)
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Length  of X_train
len(x_train)
# Out:
# 17290

# %%
#length of x_test 
len(x_test)
# Out:
# 4323

# %% [markdown]
# ## Step 6 : Accuracy and Evaluation

# %%
#finding total accuracy comes in LinearRegression
print("Acuuracy of training data=",reg.score(x_train, y_train)) #accuracy of trained data
print("Acuuracy of testing data=",reg.score(x_test, y_test)) #accuracy of test data
# Out:
# Acuuracy of training data= 0.6954859820432642
# Acuuracy of testing data= 0.7156152938565365

# %%
#finding prediction in array form
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([[ 714313.29153182],
#        [1422462.39996574],
#        [ 419806.56361427],
#        ...,
#        [ 522114.84515218],
#        [ 174723.95094931],
#        [ 260992.92524155]])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# House price prediction using machine learning is a valuable and practical application with significant implications for both homebuyers and sellers, as well as real estate professionals. After conducting extensive research and implementing various machine learning models

# %% [markdown]
# <center><img src="https://i.ibb.co/WfJFDyf/Danke.png"></center>
